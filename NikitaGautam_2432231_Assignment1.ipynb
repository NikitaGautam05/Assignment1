# %%
import pandas as pd

# %% [markdown]
# 1 Problem - 1: Getting Started with Data Exploration - Some Warm up
# Exercises:
# 1. Data Exploration and Understanding:
# • Dataset Overview:
# 1. Load the dataset and display the first 10 rows.
# 2. Identify the number of rows and columns in the dataset.
# 3. List all the columns and their data types.

# %%
df=pd.read_csv("/content/drive/MyDrive/Data/WHR-2024-5CS037.csv")
df.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %%
# 2
no_of_row=df.shape[0]
no_of_column=df.shape[1]
print("Number of row:",no_of_row)
print("Number of column:",no_of_column)
# Out:
# Number of row: 143
# Number of column: 9

# %%
# 3
column_type=df[df.columns].dtypes
print(column_type)
# Out:
# Country name                     object
# score                           float64
# Log GDP per capita              float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# Dystopia + residual             float64
# dtype: object

# %% [markdown]
# • Basic Statistics:
# 1. Calculate the mean, median, and standard deviation for the Score column.
# 2. Identify the country with the highest and lowest happiness scores.

# %%
# 1
score_mean=df['score'].mean()
score_median=df['score'].median()
score_SD=df['score'].std()
print("Mean of score:",score_mean)
print("Median of score:",score_median)
print("Standard deviation of score:",score_SD)
# Out:
# Mean of score: 5.52758041958042
# Median of score: 5.785
# Standard deviation of score: 1.1707165099442995

# %%
# 2
high_happiness=df[df['score']==df['score'].max()][['Country name','score']]
low_happiness=df[df['score']==df['score'].min()][['Country name','score']]
print("Country with highest happiness score:",high_happiness)
print("Country with lowest happiness score:",low_happiness)
# Out:
# Country with highest happiness score:   Country name  score
# 0      Finland  7.741
# Country with lowest happiness score:     Country name  score
# 142  Afghanistan  1.721

# %% [markdown]
# 1. Check if there are any missing values in the dataset. If so, display the total count for each column.

# %%
missing_value=df.isnull(),True
print(missing_value)
# Out:
# (     Country name  score  Log GDP per capita  Social support  \
# 0           False  False               False           False
# 1           False  False               False           False
# 2           False  False               False           False
# 3           False  False               False           False
# 4           False  False               False           False
# ..            ...    ...                 ...             ...
# 138         False  False               False           False
# 139         False  False               False           False
# 140         False  False               False           False
# 141         False  False               False           False
# 142         False  False               False           False
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                      False                         False       False
# 1                      False                         False       False
# ...

# %%
df.count()
# Out:
# Country name                    143
# score                           143
# Log GDP per capita              140
# Social support                  140
# Healthy life expectancy         140
# Freedom to make life choices    140
# Generosity                      140
# Perceptions of corruption       140
# Dystopia + residual             140
# dtype: int64

# %% [markdown]
# • Filtering and Sorting:
# 1. Filter the dataset to show only the countries with a Score greater than 7.5.
# 2. For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the
# top 10 rows.s

# %%
# 1
filtered=df[df['score']>7.5][['Country name','score']]
print(filtered)
# Out:
#   Country name  score
# 0      Finland  7.741
# 1      Denmark  7.583
# 2      Iceland  7.525

# %%
# 2
sorted_df=df.sort_values(by='Log GDP per capita',ascending=False)
print(sorted_df.head(10))
# Out:
#                  Country name  score  Log GDP per capita  Social support  \
# 7                  Luxembourg  7.122               2.141           1.355
# 16                    Ireland  6.838               2.129           1.390
# 29                  Singapore  6.523               2.118           1.361
# 21       United Arab Emirates  6.733               1.983           1.164
# 8                 Switzerland  7.060               1.970           1.425
# 6                      Norway  7.302               1.952           1.517
# 22              United States  6.725               1.939           1.392
# 85  Hong Kong S.A.R. of China  5.316               1.909           1.184
# 1                     Denmark  7.583               1.908           1.520
# 5                 Netherlands  7.319               1.901           1.462
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 7                     0.708                         0.801       0.146
# ...

# %% [markdown]
# • Adding New Columns:
# 1. Create a new column called Happiness Category that categorizes countries into three categories
# based on their Score:
#
# Low − (Score < 4)
# Medium − (4 ≤ Score ≤ 6)
# High − (Score > 6)

# %%
df['Happiness Category']=df['score'].apply (lambda x:'Low' if x<4  else 'Medium' if 4<=x<=6 else 'High' )
# res=df[['score','Happiness Category']]
# print(res.head())
print(df)
# Out:
#          Country name  score  Log GDP per capita  Social support  \
# 0             Finland  7.741               1.844           1.572
# 1             Denmark  7.583               1.908           1.520
# 2             Iceland  7.525               1.881           1.617
# 3              Sweden  7.344               1.878           1.501
# 4              Israel  7.341               1.803           1.513
# ..                ...    ...                 ...             ...
# 138  Congo (Kinshasa)  3.295               0.534           0.665
# 139      Sierra Leone  3.245               0.654           0.566
# 140           Lesotho  3.186               0.771           0.851
# 141           Lebanon  2.707               1.377           0.577
# 142       Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                      0.695                         0.859       0.142
# ...

# %% [markdown]
# 2. Data Visualizations:
# • Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.
# • Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart.
# • Plot a histogram for the Score column to show its distribution and also interpret.
# • Scatter Plot: Plot a scatter plot between GDP per Capita and Score to visualize their relationship.

# %%
# bar graph for happiest
import matplotlib.pyplot as plt
bar_df=df.sort_values(by='score',ascending=False)
res=bar_df.head(10)
res.plot(x='Country name',y='score',kind='bar',color='blue')
plt.show()

# %%
# line plot for unhappiest

unhappy = df.sort_values(by='score', ascending=True)
unhappy_df = unhappy.head(10)

# Line plot
plt.figure(figsize=(10, 6))
plt.plot(unhappy_df['Country name'], unhappy_df['score'], marker='o', color='pink')
plt.title('Top 10 Unhappiest Countries')
plt.xlabel('Country')
plt.ylabel('Happiness Score')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# histogram for the Score column to show its distribution and also interpret.
import seaborn as sns
import numpy as np

plt.figure(figsize=(8, 6))
bins=int(np.sqrt(len(df['score'])))
sns.histplot(df['score'], bins=bins, color='skyblue', edgecolor='black', kde=True)
plt.title("Distribution of Happiness Scores")
plt.xlabel("Happiness Score")
plt.ylabel("Frequency")
plt.show()

# %%
# Plot a scatter plot between GDP per Capita and Score to visualize their relationship.
sct=df[['Log GDP per capita','score']]
scatter=sct.plot(x='Log GDP per capita',y='score',kind='scatter',color='red',title='Scatter Plot')
plt.show()

# %% [markdown]
# Task - 1 - Setup Task - Preparing the South-Asia Dataset:
# Steps:
# 1. Define the countries in South Asia with a list for example:
# south asian countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
#
# "Maldives", "Nepal", "Pakistan", "Srilanka"]
#
# 2. Use the list from step - 1 to filtered the dataset {i.e. filtered out matching dataset from list.}
# 3. Save the filtered dataframe as separate CSV files for future use.

# %%
# 1
south_asian_countries=["Afghanistan","Bangladesh","Bhutan","India","Maldives","Nepal","Pakistan","Sri Lanka"]
df=pd.read_csv("/content/drive/MyDrive/Data/WHR-2024-5CS037.csv")

# %%
# 2
filtered_df=df[df['Country name'].isin(south_asian_countries)]
print(filtered_df)
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %%
#3
filtered_df.to_csv("South_Asian_data.csv ")
print("sucessfully converted")
# Out:
# sucessfully converted

# %% [markdown]
# Tasks:
# 1. Using the SouthAsia DataFrame, create a new column called Composite Score that combines the
# following metrics:
#
# Composite Score = 0.40 × GDP per Capita + 0.30 × Social Support
#
# + 0.30 × Healthy Life Expectancy
# 2. Rank the South Asian countries based on the Composite Score in descending order.
# 3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.
# 4. Discuss whether the rankings based on the Composite Score align with the original Score - support your
# discussion with some visualization plot.

# %%
Sa_df=pd.read_csv("/content/South_Asian_data.csv ")
print(Sa_df)
Sa_df['Composite score']=(0.40*Sa_df['Log GDP per capita'])+(0.30*Sa_df['Social support'])+(0.30*Sa_df['Healthy life expectancy'])
print(Sa_df)
# Out:
#    Unnamed: 0 Country name  score  Log GDP per capita  Social support  \
# 0          92        Nepal  5.158               0.965           0.990
# 1         107     Pakistan  4.657               1.069           0.600
# 2         125        India  4.054               1.166           0.653
# 3         127    Sri Lanka  3.898               1.361           1.179
# 4         128   Bangladesh  3.886               1.122           0.249
# 5         142  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
# 3                    0.586                         0.583       0.144
# 4                    0.513                         0.775       0.140
# ...

# %%
# 2
ranking=Sa_df.sort_values(by='Composite score',ascending=False)
print(ranking)
# Out:
#    Unnamed: 0 Country name  score  Log GDP per capita  Social support  \
# 3         127    Sri Lanka  3.898               1.361           1.179
# 0          92        Nepal  5.158               0.965           0.990
# 2         125        India  4.054               1.166           0.653
# 1         107     Pakistan  4.657               1.069           0.600
# 4         128   Bangladesh  3.886               1.122           0.249
# 5         142  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 3                    0.586                         0.583       0.144
# 0                    0.443                         0.653       0.209
# 2                    0.417                         0.767       0.174
# 1                    0.321                         0.542       0.144
# 4                    0.513                         0.775       0.140
# ...

# %%
# 3
ranking=Sa_df.sort_values(by='Composite score',ascending=False)
print(ranking)
top_countries=ranking.head(5)
print(top_countries)
top_countries.plot(x='Country name',y='Composite score',kind='barh',color='pink',title='Horizontal bar chart')
plt.xlabel('Composite Score')
plt.show()
# Out:
#    Unnamed: 0 Country name  score  Log GDP per capita  Social support  \
# 3         127    Sri Lanka  3.898               1.361           1.179
# 0          92        Nepal  5.158               0.965           0.990
# 2         125        India  4.054               1.166           0.653
# 1         107     Pakistan  4.657               1.069           0.600
# 4         128   Bangladesh  3.886               1.122           0.249
# 5         142  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 3                    0.586                         0.583       0.144
# 0                    0.443                         0.653       0.209
# 2                    0.417                         0.767       0.174
# 1                    0.321                         0.542       0.144
# 4                    0.513                         0.775       0.140
# ...

# %%
# 4
# Assuming the original score is in a column named 'Score'
top_countries['Original Score'] = top_countries['score']

# Plotting side-by-side bar chart for comparison
plt.figure(figsize=(10, 6))
plt.barh(top_countries['Country name'], top_countries['Composite score'], label='Composite Score', color='blue', alpha=0.7)
plt.barh(top_countries['Country name'], top_countries['Original Score'], label='Original Score', color='green', alpha=0.7)
plt.xlabel('Score')
plt.title('Comparison of Composite Score and Original Score for Top 5 Countries')
plt.gca().invert_yaxis()
plt.legend()
plt.show()
# Out:
# <ipython-input-23-125dcfd58469>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_countries['Original Score'] = top_countries['score']

# %% [markdown]
# Task - 3 - Outlier Detection:
# Tasks:
# 1. Identify outlier countries in South Asia based on their Score and GDP per Capita.
# 2. Define outliers using the 1.5 × IQR rule.
# 3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers
# in a different color.
# 4. Discuss the characteristics of these outliers and their potential impact on regional averages.

# %%
# 1
q1=Sa_df['Composite score'].quantile(0.25)
q3=Sa_df['Composite score'].quantile(0.75)
iqr=q3-q1
lower_value=q1-1.5*iqr
upper_value=q3+1.5*iqr
outliers_cs = Sa_df[(Sa_df['Composite score'] < lower_value) | (Sa_df['Composite score'] > upper_value)][['Country name','Composite score']]
print(outliers_cs)
# Out:
#   Country name  Composite score
# 3    Sri Lanka           1.0739
# 5  Afghanistan           0.3238

# %%
# 1
q1=Sa_df['Log GDP per capita'].quantile(0.25)
q3=Sa_df['Log GDP per capita'].quantile(0.75)
iqr=q3-q1
lower_value=q1-1.5*iqr
upper_value=q3+1.5*iqr
outliers_gdp = Sa_df[(Sa_df['Log GDP per capita'] < lower_value) | (Sa_df['Log GDP per capita'] > upper_value)][['Country name','Log GDP per capita']]
print(outliers_gdp)
# Out:
#   Country name  Log GDP per capita
# 5  Afghanistan               0.628

# %% [markdown]
# Define outliers using the 1.5 × IQR rule.
# 1.5 is exactly used in outliers because it is more appropriate value to count  outlier. 1.5 ignores all the small difference so outliers can actually be calculated.

# %% [markdown]
# <!-- leftttt -->

# %%
# 3
Q1_score = Sa_df['score'].quantile(0.25)
Q3_score = Sa_df['score'].quantile(0.75)
IQR_score = Q3_score - Q1_score

Q1_gdp = Sa_df['Log GDP per capita'].quantile(0.25)
Q3_gdp = Sa_df['Log GDP per capita'].quantile(0.75)
IQR_gdp = Q3_gdp - Q1_gdp
# 2. Define outliers using the 1.5 × IQR rule
outliers_s = Sa_df[(Sa_df['score'] < (Q1_score - 1.5 * IQR_score)) |
                                (Sa_df['score'] > (Q3_score + 1.5 * IQR_score))]

gdp_outliers = Sa_df[(Sa_df['Log GDP per capita'] < (Q1_gdp - 1.5 * IQR_gdp)) |
                               (Sa_df['Log GDP per capita'] > (Q3_gdp + 1.5 * IQR_gdp))]

outliers = pd.concat([outliers_s, gdp_outliers]).drop_duplicates()

# 3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers in a different color.
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Log GDP per capita', y='score', data=Sa_df, color='blue', label='Composite Score')
sns.scatterplot(x='Log GDP per capita', y='score', data=outliers_s, color='brown', label='original score')
plt.title('Scatter Plot: GDP per Capita vs Score with Outliers Highlighted')
plt.xlabel('Log GDP per capita')
plt.ylabel('Score')
plt.legend()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming Sa_df is your South Asia DataFrame
sorted_df = Sa_df.sort_values(by='Log GDP per capita')

# Calculate IQR for score and GDP per capita
score_q1, score_q3 = sorted_df['score'].quantile([0.25, 0.75])
gdp_q1, gdp_q3 = sorted_df['Log GDP per capita'].quantile([0.25, 0.75])

iqr_score = score_q3 - score_q1
iqr_gdp = gdp_q3 - gdp_q1

score_lower_bound = score_q1 - 1.5 * iqr_score
score_upper_bound = score_q3 + 1.5 * iqr_score

gdp_lower_bound = gdp_q1 - 1.5 * iqr_gdp
gdp_upper_bound = gdp_q3 + 1.5 * iqr_gdp

# Identify outliers
outliers = sorted_df[
    (sorted_df['score'] < score_lower_bound) | (sorted_df['score'] > score_upper_bound) |
    (sorted_df['Log GDP per capita'] < gdp_lower_bound) | (sorted_df['Log GDP per capita'] > gdp_upper_bound)
]

# Plot line graph
plt.figure(figsize=(12, 6))
plt.plot(sorted_df['Log GDP per capita'], sorted_df['score'], marker='o', label='Trend', color='purple', alpha=0.6)

# Annotate all countries (South Asia) except duplicates
for _, row in sorted_df.iterrows():
    plt.text(row['Log GDP per capita'], row['score'], row['Country name'], fontsize=8, color='black', ha='center', va='bottom')

# Add labels and title
plt.title('Line Graph Showcasing Outliers by Country (South Asia)', fontsize=14)
plt.xlabel('Log GDP per Capita', fontsize=12)
plt.ylabel('Score', fontsize=12)
plt.grid(alpha=0.3)
plt.show()


import pandas as pd
import matplotlib.pyplot as plt

# Assuming Sa_df is your South Asia DataFrame
sorted_df = Sa_df.sort_values(by='Log GDP per capita')

# Calculate IQR for score and GDP per capita
score_q1, score_q3 = sorted_df['score'].quantile([0.25, 0.75])
gdp_q1, gdp_q3 = sorted_df['Log GDP per capita'].quantile([0.25, 0.75])

iqr_score = score_q3 - score_q1
iqr_gdp = gdp_q3 - gdp_q1

score_lower_bound = score_q1 - 1.5 * iqr_score
score_upper_bound = score_q3 + 1.5 * iqr_score

gdp_lower_bound = gdp_q1 - 1.5 * iqr_gdp
gdp_upper_bound = gdp_q3 + 1.5 * iqr_gdp

# Identify outliers
outliers = sorted_df[
    (sorted_df['score'] < score_lower_bound) | (sorted_df['score'] > score_upper_bound) |
    (sorted_df['Log GDP per capita'] < gdp_lower_bound) | (sorted_df['Log GDP per capita'] > gdp_upper_bound)
]

# Remove outliers from the dataset (including Afghanistan if it is an outlier)
filtered_df = sorted_df[~sorted_df.index.isin(outliers.index)]

# Plot line graph for the filtered dataset (outliers removed)
plt.figure(figsize=(12, 6))
plt.plot(filtered_df['Log GDP per capita'], filtered_df['score'], marker='o', label='Trend', color='blue', alpha=0.6)

# Annotate all countries in the filtered dataset
for _, row in filtered_df.iterrows():
    plt.text(row['Log GDP per capita'], row['score'], row['Country name'], fontsize=8, color='black', ha='center', va='bottom')

# Add labels and title
plt.title('Line Graph Showcaisng Outliers by Country (South Asia)', fontsize=14)
plt.xlabel('Log GDP per Capita')
plt.ylabel('Score')
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# Task - 4 - Exploring Trends Across Metrics:
# Tasks:
# 1. Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation
# {pearson correlation} with the Score for South Asian countries.
# 2. Create scatter plots with trendlines for these metrics against the Score.
# 3. Identify and discuss the strongest and weakest relationships between these metrics and the Score for
# South Asian countries.

# %%
# 1
freedom_to_make_life_choices_correlation =Sa_df['Freedom to make life choices'].corr(Sa_df['score'])
generosity_correlation = Sa_df['Generosity'].corr(Sa_df['score'])
print("Correlation between Freedom to Make Life Choices and Score:", freedom_to_make_life_choices_correlation)
print("Correlation between Generosity and Score:", generosity_correlation)
# Out:
# Correlation between Freedom to Make Life Choices and Score: 0.8005185224163315
# Correlation between Generosity and Score: 0.874512371253192

# %%
# 2
sns.lmplot(data=Sa_df,x='Freedom to make life choices',y='score')
sns.lmplot(data=Sa_df,x='Generosity',y='score')
# score is dependent variable so it will be on yaxis
plt.show()

# %% [markdown]
# Between these two metrices it can be distinguished that generosity has stronger relation with score than that of Freedom to make life choice value. since, the value of both coorelation is positive but generosity value is closer to 1 therefore, it is considered to be the one having stronger relation.

# %% [markdown]
# Task - 5 - Gap Analysis:
# Tasks:
# 1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score
# for each South Asian country.
# 2. Rank the South Asian countries by this gap in both ascending and descending order.
# 3. Highlight the top 3 countries with the largest positive and negative gaps using a bar chart.
# 4. Analyze the reasons behind these gaps and their implications for South Asian countries.

# %%
# 1
Sa_df['GDP-Score Gap']=Sa_df['Log GDP per capita']-Sa_df['score']
print(Sa_df)
# Out:
#    Unnamed: 0 Country name  score  Log GDP per capita  Social support  \
# 0          92        Nepal  5.158               0.965           0.990
# 1         107     Pakistan  4.657               1.069           0.600
# 2         125        India  4.054               1.166           0.653
# 3         127    Sri Lanka  3.898               1.361           1.179
# 4         128   Bangladesh  3.886               1.122           0.249
# 5         142  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
# 3                    0.586                         0.583       0.144
# 4                    0.513                         0.775       0.140
# ...

# %%
# 2
asc_ranking=Sa_df.sort_values(by='GDP-Score Gap',ascending=True)
print(asc_ranking)
# Out:
#    Unnamed: 0 Country name  score  Log GDP per capita  Social support  \
# 0          92        Nepal  5.158               0.965           0.990
# 1         107     Pakistan  4.657               1.069           0.600
# 2         125        India  4.054               1.166           0.653
# 4         128   Bangladesh  3.886               1.122           0.249
# 3         127    Sri Lanka  3.898               1.361           1.179
# 5         142  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
# 4                    0.513                         0.775       0.140
# 3                    0.586                         0.583       0.144
# ...

# %%
dsc_ranking=Sa_df.sort_values(by ='GDP-Score Gap',ascending=False)
print(dsc_ranking)
# Out:
#    Unnamed: 0 Country name  score  Log GDP per capita  Social support  \
# 5         142  Afghanistan  1.721               0.628           0.000
# 3         127    Sri Lanka  3.898               1.361           1.179
# 4         128   Bangladesh  3.886               1.122           0.249
# 2         125        India  4.054               1.166           0.653
# 1         107     Pakistan  4.657               1.069           0.600
# 0          92        Nepal  5.158               0.965           0.990
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 5                    0.242                         0.000       0.091
# 3                    0.586                         0.583       0.144
# 4                    0.513                         0.775       0.140
# 2                    0.417                         0.767       0.174
# 1                    0.321                         0.542       0.144
# ...

# %%
# 3
largest_pos_gap=(dsc_ranking.head(3))
largest_neg_gap=(asc_ranking.head(3))
print("Largest positive gap\n",largest_pos_gap)
print("Largest negative gap\n",largest_neg_gap)
# Out:
# Largest positive gap
#     Unnamed: 0 Country name  score  Log GDP per capita  Social support  \
# 5         142  Afghanistan  1.721               0.628           0.000
# 3         127    Sri Lanka  3.898               1.361           1.179
# 4         128   Bangladesh  3.886               1.122           0.249
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 5                    0.242                         0.000       0.091
# 3                    0.586                         0.583       0.144
# 4                    0.513                         0.775       0.140
#
#    Perceptions of corruption  Dystopia + residual  Composite score  \
# 5                      0.088                0.672           0.3238
# 3                      0.031                0.014           1.0739
# 4                      0.167                0.919           0.6774
#
#    GDP-Score Gap
# 5         -1.093
# 3         -2.537
# 4         -2.764
# Largest negative gap
# ...

# %%
largest_pos_gap.plot(x='Country name',y="GDP-Score Gap",color='blue',kind='barh',title='Largest positive gap')
plt.ylabel('GDP score gap')
plt.show()

# %%
largest_neg_gap.plot(x='Country name',y="GDP-Score Gap",color='red',kind='barh',title='Largest negative gap')
plt.ylabel('GDP score gap')
plt.show()

# %% [markdown]
# Tasks:
# 1. Similar in Task - 1 of Problem 2 create a dataframe from middle eastern countries. For hint use the
# following list:
# middle east countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
# "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
#
# "United Arab Emirates", "Yemen"]

# %%
countries={"Bahrain", "Iran", "Iraq", "Israel", "Jordan", "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
"United Arab Emirates", "Yemen"}
pd.DataFrame(countries)
filtering=df[df['Country name'].isin(countries)]
print(filtering)
filtering.to_csv("middle_eastern_data.csv")
print("sucessfully converted")
# Out:
#              Country name  score  Log GDP per capita  Social support  \
# 4                  Israel  7.341               1.803           1.513
# 12                 Kuwait  6.951               1.845           1.364
# 21   United Arab Emirates  6.733               1.983           1.164
# 27           Saudi Arabia  6.594               1.842           1.361
# 61                Bahrain  5.959                 NaN             NaN
# 91                   Iraq  5.166               1.249           0.996
# 99                   Iran  4.923               1.435           1.136
# 124                Jordan  4.186               1.262           0.983
# 132                 Yemen  3.561               0.671           1.281
# 141               Lebanon  2.707               1.377           0.577
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                      0.740                         0.641       0.153
# ...

# %% [markdown]
# 1. Descriptive Statistics:
# • Calculate the mean, Standard deviation of the score for both South Asia and Middle East.
# • Which region has higher happiness Scores on average?

# %%
# 1
Me_df=pd.read_csv("/content/middle_eastern_data.csv")
# for South asia
sa_mean=Sa_df['score'].mean()
sa_median=Sa_df['score'].median()
sa_std=Sa_df['score'].std()
print("\nMean of score of south asia:",sa_mean)
print("Median of score of south asia:",sa_median)
print("Standard deviation of score of south asia:",sa_std)
# for middle east
me_mean=Me_df['score'].mean()
me_median=Me_df['score'].median()
me_std=Me_df['score'].std()
print("\nMean of score of middle east:",me_mean)
print("Median of score of middle east:",me_median)
print("Standard deviation of score of middle east:",me_std)
# Out:
# Mean of score of south asia: 3.895666666666667
# Median of score of south asia: 3.976
# Standard deviation of score of south asia: 1.1770690152521504
#
# Mean of score of middle east: 5.412100000000001
# Median of score of middle east: 5.5625
# Standard deviation of score of middle east: 1.5662011684327144

# %% [markdown]
# 2. Top and Bottom Performers:
# • Identify the top 3 and bottom 3 countries in each region based on the score.
# • Plot bar charts comparing these charts.

# %%
# 2
rank_S=Sa_df.sort_values(by='score',ascending=False)
rank_M=Me_df.sort_values(by='score',ascending=False)
rank_Sa=(rank_S.head(3))
rank_Me=(rank_M.head(3))
print("Top 3 countries in south asia\n",rank_Sa)
print("\nTop 3 countries in middle east\n",rank_Me)
# Out:
# Top 3 countries in south asia
#     Unnamed: 0 Country name  score  Log GDP per capita  Social support  \
# 0          92        Nepal  5.158               0.965           0.990
# 1         107     Pakistan  4.657               1.069           0.600
# 2         125        India  4.054               1.166           0.653
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
#
#    Perceptions of corruption  Dystopia + residual  Composite score  \
# 0                      0.115                1.783           0.8159
# 1                      0.074                1.907           0.7039
# 2                      0.122                0.756           0.7874
#
#    GDP-Score Gap
# 0         -4.193
# 1         -3.588
# 2         -2.888
#
# ...

# %%
rank_Sa.plot(x='Country name',y='score',color='red',kind='bar',title='Top South Asian chart')
plt.ylabel('score')
plt.show()

# %%
rank_Me.plot(x='Country name',y='score',color='pink',kind='bar',title='Top Middle East chart')
plt.ylabel('score')
plt.show()

# %%
rank_S=Sa_df.sort_values(by='score',ascending=True)
rank_M=Me_df.sort_values(by='score',ascending=True)
rank_Sa_b=(rank_S.head(3))
rank_Me_b=(rank_M.head(3))
print("Top 3 countries in south asia\n",rank_Sa_b)
print("\nTop 3 countries in middle east\n",rank_Me_b)
# Out:
# Top 3 countries in south asia
#     Unnamed: 0 Country name  score  Log GDP per capita  Social support  \
# 5         142  Afghanistan  1.721               0.628           0.000
# 4         128   Bangladesh  3.886               1.122           0.249
# 3         127    Sri Lanka  3.898               1.361           1.179
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 5                    0.242                         0.000       0.091
# 4                    0.513                         0.775       0.140
# 3                    0.586                         0.583       0.144
#
#    Perceptions of corruption  Dystopia + residual  Composite score  \
# 5                      0.088                0.672           0.3238
# 4                      0.167                0.919           0.6774
# 3                      0.031                0.014           1.0739
#
#    GDP-Score Gap
# 5         -1.093
# 4         -2.764
# 3         -2.537
#
# ...

# %%
rank_Sa_b.plot(x='Country name',y='score',color='blue',kind='bar',title='Bottom South Asian chart')
plt.ylabel('score')
plt.show()

# %%
rank_Me_b.plot(x='Country name',y='score',color='purple',kind='bar',title='Bottom middle east chart')
plt.ylabel('score')
plt.show()

# %% [markdown]
# 3. Metric Comparisons:
# • Compare key metrics like GDP per Capita, Social Support, and Healthy Life Expectancy
# between the regions using grouped bar charts.
# • Which metrics show the largest disparity between the two regions?

# %%
import numpy as np
import matplotlib.pyplot as plt

# Example data (replace this with your actual data)
metrics = ['Log GDP per capita', 'Social support', 'Healthy life expectancy']
region_Sa_values = Sa_df[metrics].mean()
region_Me_values = Me_df[metrics].mean()

# x is array like index looping that takes corresponding value?
x = np.arange(len(metrics))
bar_width = 0.35
plt.figure(figsize=(10, 6))

# Bars for Region_Sa
# x- and x+ so they dont overlaap
plt.bar(x - bar_width/2, region_Sa_values, bar_width, label='Region_Sa', color='purple')

# Bars for Region_Me
plt.bar(x + bar_width/2, region_Me_values, bar_width, label='Region_Me', color='black')

# Add labels and titles
plt.xlabel('Metrics')
plt.ylabel('Average Values')
plt.title('Comparison of Metrics Between Region_Sa and Region_Me')
plt.xticks(x, metrics)  # shows metrices in x axis instead of number
plt.legend()

# Show grid and plot)
plt.tight_layout()
plt.show()

# %% [markdown]
# • Which metrics show the largest disparity between the two regions? baki xa#

# %% [markdown]
# 4. Happiness Disparity:
# • Compute the range (max - min) and coefficient of variation (CV) for Score in both regions.
# • Which region has greater variability in happiness?

# %%
Sa_range=Sa_df['score'].max()-Sa_df['score'].min()
Me_range=Me_df['score'].max()-Me_df['score'].min()
cv_Sa=Sa_df['score'].std()/Sa_df['score'].mean()
cv_Me=Me_df['score'].std()/Me_df['score'].mean()
print("South asian range:",Sa_range)
print("Middle east range:",Me_range)
print("South asian CV:",cv_Sa)
print("Middle east CV:",cv_Me)
# Out:
# South asian range: 3.4370000000000003
# Middle east range: 4.634
# South asian CV: 0.3021482883337427
# Middle east CV: 0.28938880812119405

# %% [markdown]
# 5. Correlation Analysis:
# • Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and
# Generosity within each region.
# • Create scatter plots to visualize and interpret the relationships.

# %%
sa_freedom=Sa_df['Freedom to make life choices'].corr(Sa_df['score'])
sa_generosity=Sa_df['Generosity'].corr(Sa_df['score'])
print("South asian freedom:", sa_freedom)
print("south asian generosity:", sa_generosity)
me_freedom=Me_df['Freedom to make life choices'].corr(Me_df['score'])
me_generoity=Me_df['Generosity'].corr(Me_df['score'])
print("middle east freedom:", freedom_to_make_life_choices_correlation)
print("middle east Generosity:", generosity_correlation)
# Out:
# South asian freedom: 0.8005185224163315
# south asian generosity: 0.874512371253192
# middle east freedom: 0.8005185224163315
# middle east Generosity: 0.874512371253192

# %%
sns.lmplot(data=Sa_df,x='Freedom to make life choices',y='score')
plt.title('South Asian freedom')
plt.show()

# %%
sns.lmplot(data=Sa_df,x='Generosity',y='score')
# score is dependent variable so it will be on yaxis
plt.title('South Asian generosity')
plt.show()

# %%
sns.lmplot(data=Me_df,x='Freedom to make life choices',y='score')
plt.title('middle east freedom')
plt.show()

# %%
sns.lmplot(data=Me_df,x='Generosity',y='score')
# score is dependent variable so it will be on yaxis
plt.title('middle east generosity')
plt.show()

# %% [markdown]
# 6. Outlier Detection:
# • Identify outlier countries in both regions based on Score and GDP per Capita.
# • Plot these outliers and discuss their implications.

# %%
me_q1=Me_df['score'].quantile(0.25)
me_q3=Me_df['score'].quantile(0.75)
me_iqr=me_q1-me_q3
me_lower_value=me_q1-1.5*iqr
me_upper_value=me_q3+1.5*iqr
outliers_middleEast_score= Me_df[(Me_df['score']< me_lower_value) | (Me_df['score']> me_upper_value)] [['Country name','score']]
print(outliers_middleEast_score)
print(outliers_s)
# Out:
#   Country name  score
# 0       Israel  7.341
# 1       Kuwait  6.951
# 8        Yemen  3.561
# 9      Lebanon  2.707

# %%
me_q1=Me_df['Log GDP per capita'].quantile(0.25)
me_q3=Me_df['Log GDP per capita'].quantile(0.75)
me_iqr=me_q1-me_q3
me_lower_value=me_q1-1.5*iqr
me_upper_value=me_q3+1.5*iqr
outliers_middleEast_gdp= Me_df[(Me_df['Log GDP per capita']< me_lower_value) | (Me_df['Log GDP per capita']> me_upper_value)] [['Country name','Log GDP per capita']]
print(outliers_middleEast_gdp)
print(outliers_gdp)
# Out:
#   Country name  Log GDP per capita
# 8        Yemen               0.671
#   Country name  Composite score  Log GDP per capita  score
# 4  Afghanistan           0.3238               0.628  1.721

# %%
outliers_middleEast_score.plot(x='Country name',y='score',color='red',marker='o',title='Outliers in middle east')
plt.ylabel('score')
# Out:
# Text(0, 0.5, 'score')

# %%
outliers_s.plot(x='Country name',y='score',color='blue',marker='o',title='Outliers in south asia')
plt.ylabel('score')
plt.show()

# %%
outliers_middleEast_gdp.plot(x='Country name',y='Log GDP per capita',color='red',marker='o',title='Outliers in middle east')
plt.ylabel('Log GDP per capita')
plt.show()

# %%
outliers_gdp.plot(x='Country name',y='Log GDP per capita',color='blue',marker='o',title='Outliers in south asia')
plt.ylabel('Log GDP per capita')
plt.show()

# %% [markdown]
# 7. Visualization:
# • Create boxplots comparing the distribution of Score between South Asia and the Middle East.
# • Interpret the key differences in distribution shapes, medians, and outliers.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

Sa_df['Region'] = 'South Asia'
Me_df['Region'] = 'Middle East'

# Combine the two DataFrames for comparison
combined_df = pd.concat([Sa_df[['Country name', 'score', 'Region']], Me_df[['Country name', 'score', 'Region']]])
sns.boxplot(x='Region', y='score', data=combined_df, palette='Set3',hue='Region')
plt.title('Comparison of Score Distribution Between South Asia and Middle East')
plt.xlabel('Region')
plt.ylabel('Score')
plt.tight_layout()
plt.show()
